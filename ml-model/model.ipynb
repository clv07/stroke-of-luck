# %%
import os
import pandas as pd
import time

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.svm import SVC
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
import model_helper_code as hc

# %%
# read in datasets
datasets = os.path.join('..', 'data', 'merged_output.csv')
df = pd.read_csv(datasets)

# %%
# seperate statement codes into columns with binary value entries
df['Statement_codes'] = df['Statement_codes'].str.split(',')
mlb = MultiLabelBinarizer()
features = mlb.fit_transform(df['Statement_codes'])
matrix = pd.DataFrame(features, columns=mlb.classes_)

# %%
# split into training and testing datasets
X_train, X_test, y_train, y_test = hc.split_dataset(matrix, df['MI_Phys'], 0.33)
# Out:
# Training datasets: 29981 samples
# Testing datasets: 14767 samples

# %%
# autoencoder
start_time = time.time()
input_dim = X_train.shape[1]
encoding_dim = 10 # how to determine 

input_layer = keras.Input(shape=(input_dim,))
encoded = layers.Dense(encoding_dim, activation='relu')(input_layer)
decoded = layers.Dense(input_dim, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_layer, decoded)
encoder = keras.Model(input_layer, encoded)  # feature extraction

# %%
# train model
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.fit(X_train, X_train, epochs=50, batch_size=32, shuffle=True, validation_data=(X_test, X_test))

# features extraction
X_train_encoded = encoder.predict(X_train)
X_test_encoded = encoder.predict(X_test)
end_time = time.time()
# Out:
# Epoch 1/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 596us/step - loss: 0.0993 - val_loss: 0.0142
# Epoch 2/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 533us/step - loss: 0.0127 - val_loss: 0.0104
# Epoch 3/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 540us/step - loss: 0.0097 - val_loss: 0.0084
# Epoch 4/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 533us/step - loss: 0.0079 - val_loss: 0.0070
# Epoch 5/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 533us/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 6/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 532us/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 7/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.0052 - val_loss: 0.0049
# Epoch 8/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 9/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 10/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 596us/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 11/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 589us/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 12/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 585us/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 13/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 14/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 538us/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 15/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 526us/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 16/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 17/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 18/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 19/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 20/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 21/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 582us/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 22/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 23/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 24/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 25/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 685us/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 26/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 27/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 28/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 29/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 529us/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 30/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 652us/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 31/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.0027 - val_loss: 0.0029
# Epoch 32/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 33/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 34/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 35/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 587us/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 36/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 524us/step - loss: 0.0027 - val_loss: 0.0029
# Epoch 37/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 38/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 39/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 534us/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 40/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 568us/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 41/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 522us/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 42/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 43/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 44/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 527us/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 45/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 46/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 47/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 48/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 49/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 50/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 579us/step - loss: 0.0026 - val_loss: 0.0028
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 224us/step
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 226us/step

# %%
# autoencoder training time in seconds
end_time - start_time
# Out:
# 26.640946865081787

# %%
# train svm
svm_model = SVC(kernel='rbf', class_weight='balanced', probability=True)
svm_model.fit(X_train_encoded, y_train)
# Out:
# SVC(class_weight='balanced', probability=True)

# %%
# evaluation
y_pred = svm_model.predict(X_test_encoded)
print('SVM Classification Report:')
print(classification_report(y_test, y_pred))
# Out:
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     14707
#            1       0.01      0.42      0.03        60
#
#     accuracy                           0.88     14767
#    macro avg       0.51      0.65      0.48     14767
# weighted avg       0.99      0.88      0.93     14767
